# %%
import seaborn as sns

# %%
import pandas as pd

bank_data = pd.read_csv('bank-additional-full.csv')

# %%
import seaborn as sns
# %matplotlib inline

tips = sns.load_dataset('tips')

# %%
sns.distplot(bank_data['age'], kde=False, bins = 30)

# %%
sns.distplot(bank_data['campaign'], kde = False, bins = 40)
bank_data['campaign'].max()
# Out:
# 56

# %%
sns.pairplot(bank_data, hue='y')

# %%
bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
ax = sns.barplot(x="y", y="age", data=bank_data)

# %%
sns.countplot(x='y', data=bank_data)

# %%
 bank_data.loc[bank_data['campaign'].idxmax()]
# Out:
# age                              32
# job                          admin.
# marital                     married
# education         university.degree
# default                     unknown
# housing                     unknown
# loan                        unknown
# contact                   telephone
# month                           may
# day_of_week                     mon
# duration                        261
# campaign                         56
# pdays                           999
# previous                          0
# poutcome                nonexistent
# emp.var.rate                    1.1
# cons.price.idx               93.994
# cons.conf.idx                 -36.4
# euribor3m                     4.858
# nr.employed                    5191
# y                                no
# Name: 4107, dtype: object

# %%
campaign = bank_data['campaign']

# %%
campaign.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: campaign, dtype: int64

# %%
sns.boxplot(x='y', y='duration', data=bank_data)

# %%
sns.jointplot(data = bank_data, x='euribor3m', y='cons.conf.idx')

# %%
sns.distplot(bank_data['euribor3m'], kde=False)

# %%
pd.set_option('display.max_colwidth', -1)
bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0  56   housemaid  married  basic.4y     no       no      no   telephone
# 1  57   services   married  high.school  unknown  no      no   telephone
# 2  37   services   married  high.school  no       yes     no   telephone
# 3  40   admin.     married  basic.6y     no       no      no   telephone
# 4  56   services   married  high.school  no       no      yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0  may   mon        ...  1         999    0         nonexistent  1.1
# 1  may   mon        ...  1         999    0         nonexistent  1.1
# 2  may   mon        ...  1         999    0         nonexistent  1.1
# 3  may   mon        ...  1         999    0         nonexistent  1.1
# 4  may   mon        ...  1         999    0         nonexistent  1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
sns.distplot(bank_data['pdays'], kde=False)

# %%
sns.heatmap(bank_data.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='y', hue = 'marital', data = bank_data, palette = 'RdBu_r')

# %%
#review dataframe info
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
sns.countplot(x = 'y', hue = 'age', data= bank_data)

# %%
bank_data['age'].max()
# Out:
# 98

# %%
def find_and_replace(df, month, prev, replace_with):
    for index, row in df.iterrows():
        if row['month'] == month:
            return
        elif row['month'] == prev:
            df.loc[index,'month'] = replace_with

# %%
bank_data = pd.read_csv('bank-additional-full.csv')

# %%
find_and_replace(bank_data, 'jun', 'may', 'may 2008')
find_and_replace(bank_data, 'jul', 'jun', 'june 2008')
find_and_replace(bank_data, 'aug', 'jul', 'july 2008')
find_and_replace(bank_data, 'oct', 'aug', 'august 2008')
find_and_replace(bank_data, 'nov', 'oct', 'october 2008')
find_and_replace(bank_data, 'dec', 'nov', 'november 2008')
find_and_replace(bank_data, 'mar', 'dec', 'december 2008')
find_and_replace(bank_data, 'apr', 'mar', 'march 2009')
find_and_replace(bank_data, 'may', 'apr', 'april 2009')
find_and_replace(bank_data, 'jun', 'may', 'may 2009')
find_and_replace(bank_data, 'jul', 'jun', 'june 2009')
find_and_replace(bank_data, 'aug', 'jul', 'july 2009')
find_and_replace(bank_data, 'sep', 'aug', 'august 2009')
find_and_replace(bank_data, 'oct', 'sep', 'september 2009')
find_and_replace(bank_data, 'nov', 'oct', 'october 2009')
find_and_replace(bank_data, 'dec', 'nov', 'november 2009')
find_and_replace(bank_data, 'mar', 'dec', 'december 2009')
find_and_replace(bank_data, 'apr', 'mar', 'march 2010')
find_and_replace(bank_data, 'may', 'apr', 'april 2010')
find_and_replace(bank_data, 'jun', 'may', 'may 2010')
find_and_replace(bank_data, 'jul', 'jun', 'june 2010')
find_and_replace(bank_data, 'aug', 'jul', 'july 2010')
find_and_replace(bank_data, 'sep', 'aug', 'august 2010')
find_and_replace(bank_data, 'oct', 'sep', 'september 2010')
find_and_replace(bank_data, 'nov', 'oct', 'october 2010')

# %%
sns.mpl.rc("figure", figsize=(9,9))
sns.countplot(x = 'y', hue = 'month', data= bank_data)

# %%
bank_data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183  73   retired      married  professional.course  no      yes     no
# 41184  46   blue-collar  married  professional.course  no      no      no
# 41185  56   retired      married  university.degree    no      yes     no
# 41186  44   technician   married  professional.course  no      no      no
# 41187  74   retired      married  professional.course  no      yes     no
#
#         contact month day_of_week ...   campaign  pdays  previous  \
# 41183  cellular  nov   fri        ...   1         999    0
# 41184  cellular  nov   fri        ...   1         999    0
# 41185  cellular  nov   fri        ...   2         999    0
# 41186  cellular  nov   fri        ...   1         999    0
# 41187  cellular  nov   fri        ...   3         999    1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41183  nonexistent -1.1          94.767         -50.8           1.028
# ...

# %%
for index, row in bank_data.iterrows():
     if row['month'] == 'nov':
        bank_data.loc[index,'month'] = 'november 2010'

# %%
sns.mpl.rc("figure", figsize=(12,6))
sns.countplot(x = 'y', hue = 'month', data= bank_data)

# %%
sns.countplot(x='y', hue = 'education', data=bank_data)

# %%
sns.countplot(x="education", data=bank_data, palette="coolwarm", order = bank_data['education'].value_counts().index)

# %%
sns.mpl.rc("figure", figsize=(35,10))

sns.countplot(x="month", data=bank_data)

# %%
sns.mpl.rc("figure", figsize=(15,10))
sns.color_palette("hls", 8)
sns.countplot(x='y', hue = 'marital', data=bank_data)

# %%
sns.countplot(x='y', hue = 'day_of_week', data=bank_data)

# %%
sns.countplot(x='y', hue = 'contact', data=bank_data)

# %%
sns.countplot(x='y', hue = 'housing', data=bank_data, palette = 'hls')

# %%
sns.countplot(x='y', hue = 'loan', data=bank_data, palette = 'hls')

# %%
sns.countplot(x='y', hue = 'default', data=bank_data, palette = 'hls')

# %%
sns.countplot(x='y', hue = 'campaign', data=bank_data, palette = 'hls')

# %%
sns.countplot(x = 'y', hue="previous", data=bank_data)

# %%
sns.countplot(x='y', hue = 'poutcome', data=bank_data, palette = 'hls')

# %%
sns.distplot(bank_data['cons.price.idx'], kde= False, bins=30)

# %%
sns.mpl.rc("figure", figsize=(60,10))
sns.pointplot(x="month", y="cons.price.idx", data = bank_data)

# %%
sns.pointplot(x="month", y="cons.conf.idx", data = bank_data)

# %%
sns.pointplot(x="month", y="nr.employed", data = bank_data)

# %%
sns.pointplot(x="month", y="euribor3m", data = bank_data)

# %%
sns.jointplot(x = 'euribor3m', y ='nr.employed', kind = 'scatter', data = bank_data)

# %%
sns.mpl.rc("figure", figsize=(60,10))
g = sns.pairplot(bank_data, vars=["euribor3m", "cons.conf.idx"], palette = 'coldwarm')

# %%
sns.pointplot(x="month", y="age", data = bank_data)

# %%
#Data preprocessing and splitting and scaling
X = bank_data.iloc[:,bank_data.columns != 'y'].values
y = bank_data.iloc[:, -1].values

# %%
sns.mpl.rc("figure", figsize=(20,10))
sns.countplot(x = 'y', hue = 'job', data= bank_data)

# %%
cm
# Out:
# array([[9006,  133],
#        [ 937,  221]], dtype=int64)

# %%
# Fitting Decision Tree Classification to the Training set
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[8650,  489],
#        [ 834,  324]], dtype=int64)

# %%
# Fitting Random Forest Classification to the Training set
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[8818,  321],
#        [ 849,  309]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          no       0.91      0.96      0.94      9139
#         yes       0.49      0.27      0.35      1158
#
# avg / total       0.86      0.89      0.87     10297

# %%
X_test
# Out:
# array([[ 1.85945577, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977],
#        [ 1.85945577, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977],
#        [ 1.85945577, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977],
#        ...,
#        [-0.53779176, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977],
#        [-0.53779176, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977],
#        [-0.53779176, -0.19161186, -0.16326132, ..., -0.49862381,
#          0.39597095, -0.18590977]])

# %%
y_test
# Out:
# array(['yes', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
y_test.max
# Out:
# <function ndarray.max>

# %%
y_test.max()
# Out:
# 'yes'

# %%
import numpy as np

# %%
c = 0
i = 0
for x in np.nditer(y_test):
    if x=='yes':
        c+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-f4fd0e2b74f1> in <module>()
#       1 c = 0
#       2 i = 0
# ----> 3 for x in np.nditer(y_test):
#       4     if x=='yes':
#       5         c+=1
#
# TypeError: Iterator operand or requested dtype holds references, but the REFS_OK flag was not enabled

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
# Fit and transform x to visualise inside a 2D feature space
X_vis = pca.fit_transform(X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b618a4d2cce9> in <module>()
#       3 pca = PCA(n_components=2)
#       4 # Fit and transform x to visualise inside a 2D feature space
# ----> 5 X_vis = pca.fit_transform(X)
#
# NameError: name 'X' is not defined

# %%
sns.jointplot
